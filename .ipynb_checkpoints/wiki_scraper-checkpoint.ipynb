# %%
import pandas as pd
import numpy as np

# %% [markdown]
# [Scraping a wikipedia table](https://scipython.com/blog/scraping-a-wikipedia-table-with-beautiful-soup/)

# %% [markdown]
# ## Governor Affiliation

# %% [markdown]
# [Wiki link](https://en.wikipedia.org/wiki/List_of_United_States_governors)

# %%
import urllib.request

url = "https://en.wikipedia.org/wiki/List_of_United_States_governors"
req = urllib.request.urlopen(url)
article = req.read().decode()

with open('usa_govs.html', 'w') as fo:
    fo.write(article)

# %%
columns=['State','Portrait','Governor','Party','Born','Prior public experience','Inauguration','End of term','Past governors']
wiki_gov_scrape = pd.DataFrame(columns=columns)

# %%
from bs4 import BeautifulSoup

# Load article, turn into soup and get the <table>s.
article = open('usa_govs.html').read()
soup = BeautifulSoup(article, 'html.parser')
tables = soup.find_all('table', class_='sortable')

# Search through the tables for the one with the headings we want.
for table in tables:
    ths = table.find_all('th')
    headings = [th.text.strip() for th in ths]
    if headings[:9] == columns:
        # this should theoretically break immediately at the first table, but it doesn't.
        break

# Extract the columns we want and write to a semicolon-delimited text file.
# The first table in the tables list represents governors
for tr in tables[0].find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue
    state,port,gov,party,born,exp,inaug,end_term,past_govs,test = [td.text.strip() for td in tds[:10]]
    d = pd.DataFrame(data={
        'State':[state],
        'Portrait':[port],
        'Governor':[gov],
        'Party':[party],
        'Born':[born],
        'Prior public experience':[exp],
        'Inauguration':[inaug],
        'End of term':[end_term],
        'Past governors':[past_govs],
        'test':[test]
    })
    wiki_gov_scrape = wiki_gov_scrape.append(d)

# %%
del wiki_gov_scrape['Portrait']
del wiki_gov_scrape['Party']
del wiki_gov_scrape['test']

# %%
wiki_gov_scrape.columns = ['state','governor','party','born','prior_exp','inauguration','end_term']
wiki_gov_scrape = wiki_gov_scrape.reset_index(drop = True)
wiki_gov_scrape['birth_date'] = wiki_gov_scrape['born'].str.extract('(\d{4}-\d{1,2}-\d{1,2})')
wiki_gov_scrape['birth_date'] = pd.to_datetime(wiki_gov_scrape['birth_date'])
wiki_gov_scrape['term_limit'] = wiki_gov_scrape['end_term'].str.contains('term limits')
wiki_gov_scrape['fed_exp'] = wiki_gov_scrape['prior_exp'].str.contains('U.S.')
wiki_gov_scrape['age'] = wiki_gov_scrape['born'].str.extract('age\s(\d\d)')
wiki_gov_scrape['inauguration'] = pd.to_datetime(wiki_gov_scrape['inauguration'])
wiki_gov_scrape['age_of_inaug'] = (wiki_gov_scrape['inauguration'] - wiki_gov_scrape['birth_date'])/365.25
wiki_gov_scrape['retiring'] = wiki_gov_scrape['end_term'].str.contains('retiring')

# %%
wiki_gov_scrape['end_term'] = wiki_gov_scrape['end_term'].str.replace('\(term limits\)','')
wiki_gov_scrape['end_term'] = wiki_gov_scrape['end_term'].str.replace('\(retiring\)','')
wiki_gov_scrape['end_term'] = wiki_gov_scrape['end_term'].str.replace(' ','')
wiki_gov_scrape['end_term'] = wiki_gov_scrape['end_term'].str.replace(' ','')
wiki_gov_scrape.loc[31,'end_term'] = 2022 # term limits take effect in state
wiki_gov_scrape.loc[47,'party'] = 'Republican' # identifies as Republican at national level
wiki_gov_scrape.loc[22,'party'] = 'Democratic' # part of Democratic party, but Democratic-Farmer-Labor name at state level

# %%
del wiki_gov_scrape['born']

# %%
wiki_gov_scrape.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         50 non-null     object
#  1   governor      50 non-null     object
#  2   party         50 non-null     object
#  3   prior_exp     50 non-null     object
#  4   inauguration  50 non-null     datetime64[ns]
#  5   end_term      50 non-null     object
#  6   birth_date    50 non-null     datetime64[ns]
#  7   term_limit    50 non-null     bool
#  8   fed_exp       50 non-null     bool
#  9   age           50 non-null     object
#  10  age_of_inaug  50 non-null     timedelta64[ns]
#  11  retiring      50 non-null     bool
# dtypes: bool(3), datetime64[ns](2), object(6), timedelta64[ns](1)
# memory usage: 3.8+ KB

# %%
wiki_gov_scrape = wiki_gov_scrape.astype({
    'end_term':int,
    'age':int
})

# %%
wiki_gov_scrape.head()
# Out:
#         state        governor       party  \
# 0     Alabama        Kay Ivey  Republican
# 1      Alaska   Mike Dunleavy  Republican
# 2     Arizona      Doug Ducey  Republican
# 3    Arkansas  Asa Hutchinson  Republican
# 4  California    Gavin Newsom  Democratic
#
#                                            prior_exp inauguration  end_term  \
# 0                     Lieutenant Governor, Treasurer   2017-04-10      2023
# 1                                      Alaska Senate   2018-12-03      2022
# 2                                          Treasurer   2015-01-05      2023
# 3  Under Secretary of Homeland Security for Borde...   2015-01-13      2023
# 4        Lieutenant Governor, Mayor of San Francisco   2019-01-07      2023
#
#   birth_date  term_limit  fed_exp  age            age_of_inaug  retiring
# 0 1944-10-15       False    False   75 72 days 11:37:49.404517     False
# 1 1961-05-05       False    False   59 57 days 13:54:49.527720     False
# 2 1964-04-09        True    False   56 50 days 17:46:26.858316     False
# 3 1950-12-03        True     True   69 64 days 02:41:38.562628     False
# 4 1967-10-10       False    False   52 51 days 05:51:52.114989     False

# %%
list_diff(wiki_gov_scrape['state'].unique(),statepop['state'].unique())
# Out:
# {'District of Columbia': 'missing from list1',
#  'Puerto Rico': 'missing from list1'}

# %%
districts = pd.DataFrame(data={
    'state':['District of Columbia', 'Puerto Rico'],
    'governor':['Muriel Bowser', 'Wanda Vázquez Garced'],
    'party':['Democratic','Republican'],
    'prior_exp':['Council of the District of Columbia','Secretary of Justice'],
    'inauguration':[pd.to_datetime('2015-Jan-2'),pd.to_datetime('2019-Aug-7')],
    'end_term':[2023,2021],
    'birth_date':[pd.to_datetime('1972-Aug-2'),pd.to_datetime('1960-July-9')],
    'term_limit':[False,False],
    'fed_exp':[False,False],
    'age':[48,60],
    'retiring':[False,False]
})

# %%
districts['age_of_inaug'] = (districts['inauguration'] - districts['birth_date'])/365.25

# %%
wiki_gov_scrape = wiki_gov_scrape.append(districts)

# %%
list_diff(wiki_gov_scrape['state'].unique(),statepop['state'].unique())
# Out:
# {}

# %% [markdown]
# ## State Legislature Makeup

# %% [markdown]
# [Wiki link](https://en.wikipedia.org/wiki/List_of_United_States_state_legislatures)

# %%
import urllib.request

url = "https://en.wikipedia.org/wiki/List_of_United_States_state_legislatures"
req = urllib.request.urlopen(url)
article = req.read().decode()

#with open('usa_legis.html', 'w') as fo:
    #fo.write(article)

# %%
columns=['state','executive','legislature_name',
         'low_house_name','low_party_strength','low_term_yrs',
         'up_house_name','up_party_strength','up_term_yrs']
wiki_leg_scrape = pd.DataFrame(columns=columns)

# %%
from bs4 import BeautifulSoup

# Load article, turn into soup and get the <table>s.
soup = BeautifulSoup(article, 'html.parser')
tables = soup.find_all('table', class_='sortable')

# Search through the tables for the one with the headings we want.
for table in tables:
    ths = table.find_all('th')
    headings = [th.text.strip() for th in ths]
    if headings[:9] == columns:
        # this should theoretically break immediately at the first table, but it doesn't.
        break
# Extract the columns we want and write to a semicolon-delimited text file.
# The first table in the tables list represents governors
for tr in tables[0].find_all('tr'):
    tds = tr.find_all('td')
    if not tds:
        continue    
    state,gov,legis_name,low_name,low_party_str,low_term_yrs,upper_name,upper_party_str,upper_term_yrs = [td.text.strip() for td in tds[:9]]
    d = pd.DataFrame(data={
        'state':[state],
        'executive':[gov],
        'legislature_name':[legis_name],
        'low_house_name':[low_name],
        'low_party_strength':[low_party_str],
        'low_term_yrs':[low_term_yrs],
        'up_house_name':[upper_name],
        'up_party_strength':[upper_party_str],
        'up_term_yrs':[upper_term_yrs]
    })
    wiki_leg_scrape = wiki_leg_scrape.append(d)

# %%
wiki_leg_scrape = wiki_leg_scrape.reset_index(drop=True)

# %%
import re

# %%
def party_finder(cell, crit = 'maj_party'):
    '''
    Extracts party information from a string in the format of "R 15-2"
    
    input
    -----
    cell: str
        String in the format of "R 15-2", with the first letter and number representing majority party
    crit: str
        Statistic to return. Can be one of "maj_party","min_party","maj_part_num","min_part_num"
    '''
    try:
    # regex creates 3 groups. See: https://regexr.com/5aibj
        stat = re.search('([A-Z])\s(\d{1,}).(\d{1,})', cell)
    #######################
        if crit == 'maj_party':
        # first group is always a letter, either R or D
            return stat.group(1)
        elif crit == 'min_party':
        # derive minority from first group
            if stat.group(1) == 'R':
                return 'D'
            elif stat.group(1) == 'D':
                return 'R'
            else:
                return 'I'
        elif crit == 'maj_party_num':
        # second group is always the majority number
            return stat.group(2)
        elif crit == 'min_party_num':
        # third group is always the minority number
            return stat.group(3)
    except AttributeError:
        return ''

# %%
for new_col in ['maj_party','maj_party_num','min_party','min_party_num']:
    wiki_leg_scrape[f'low_{new_col}'] = wiki_leg_scrape['low_party_strength'].apply(party_finder,crit=new_col)
    wiki_leg_scrape[f'up_{new_col}'] = wiki_leg_scrape['up_party_strength'].apply(party_finder,crit=new_col)

# %%
def vac_finder(cell):
    '''
    Finds the number of vacancies in the state legislature
    '''
    vac_search = re.search('(\d{1,})\svac',cell)
    if vac_search == None:
        return np.nan
    else:
        return vac_search.group(1)

# %%
for col in ['up','low']:
    wiki_leg_scrape[f'{col}_vacancies'] = wiki_leg_scrape[f'{col}_party_strength'].apply(vac_finder)

# %%
wiki_leg_scrape
# Out:
#              state executive         legislature_name  \
# 0          Alabama  Governor              Legislature
# 1           Alaska  Governor              Legislature
# 2          Arizona  Governor        State Legislature
# 3         Arkansas  Governor         General Assembly
# 4       California  Governor  State Legislature[nb 1]
# 5         Colorado  Governor         General Assembly
# 6      Connecticut  Governor         General Assembly
# 7         Delaware  Governor         General Assembly
# 8          Florida  Governor              Legislature
# 9          Georgia  Governor         General Assembly
# 10          Hawaii  Governor        State Legislature
# 11           Idaho  Governor              Legislature
# 12        Illinois  Governor         General Assembly
# 13         Indiana  Governor         General Assembly
# 14            Iowa  Governor         General Assembly
# 15          Kansas  Governor              Legislature
# 16        Kentucky  Governor         General Assembly
# 17       Louisiana  Governor  State Legislature[nb 2]
# 18           Maine  Governor              Legislature
# 19        Maryland  Governor         General Assembly
# 20   Massachusetts  Governor            General Court
# 21        Michigan  Governor              Legislature
# 22       Minnesota  Governor              Legislature
# 23     Mississippi  Governor              Legislature
# 24        Missouri  Governor         General Assembly
# 25         Montana  Governor              Legislature
# 26        Nebraska  Governor              Legislature
# 27          Nevada  Governor              Legislature
# 28   New Hampshire  Governor            General Court
# 29      New Jersey  Governor              Legislature
# 30      New Mexico  Governor              Legislature
# 31        New York  Governor                [Unnamed]
# 32  North Carolina  Governor         General Assembly
# 33    North Dakota  Governor     Legislative Assembly
# 34            Ohio  Governor         General Assembly
# 35        Oklahoma  Governor              Legislature
# 36          Oregon  Governor     Legislative Assembly
# 37    Pennsylvania  Governor         General Assembly
# 38    Rhode Island  Governor         General Assembly
# 39  South Carolina  Governor         General Assembly
# 40    South Dakota  Governor              Legislature
# 41       Tennessee  Governor         General Assembly
# 42           Texas  Governor              Legislature
# 43            Utah  Governor  State Legislature[nb 5]
# 44         Vermont  Governor         General Assembly
# 45        Virginia  Governor         General Assembly
# 46      Washington  Governor  State Legislature[nb 6]
# 47   West Virginia  Governor              Legislature
# 48       Wisconsin  Governor              Legislature
# 49         Wyoming  Governor              Legislature
#
#               low_house_name                 low_party_strength low_term_yrs  \
# 0   House of Representatives                     R 75–28, 1 vac            4
# 1   House of Representatives  Coalition 23 (15D, 6R, 2 ind)–17R            2
# 2   House of Representatives                            R 31-29            2
# 3   House of Representatives                     R 76–25, 2 vac            2
# 4             State Assembly              D 61–17, 1 ind, 1 vac            2
# 5   House of Representatives                            D 41–24            2
# 6   House of Representatives                            D 91–60            2
# 7   House of Representatives                            D 26–15            2
# 8   House of Representatives                     R 72–46, 2 vac            2
# 9   House of Representatives                           R 105–75            2
# 10  House of Representatives                             D 46–5            2
# 11  House of Representatives                            R 56–14            2
# 12  House of Representatives                     D 73–44, 1 vac            2
# 13  House of Representatives                     R 66–33, 1 vac            2
# 14  House of Representatives                            R 53–47            2
# 15  House of Representatives                            R 84–41            2
# 16  House of Representatives                            R 62–38            2
# 17  House of Representatives                     R 68–35, 2 ind            4
# 18  House of Representatives              D 87–56, 6 ind, 2 vac            2
# 19        House of Delegates                            D 99–42            4
# 20  House of Representatives             D 127–31, 1 ind, 1 vac            2
# 21  House of Representatives                     R 58–51, 1 vac            2
# 22  House of Representatives                 D 75–55, 4 New Rep            2
# 23  House of Representatives              R 73–45, 1 Ind, 3 vac            4
# 24  House of Representatives                    R 113–48, 2 vac            2
# 25  House of Representatives                            R 58–42            2
# 26
# 27                  Assembly                            D 29–13            2
# 28  House of Representatives           D 231–158, 1 ind, 10 vac            2
# 29          General Assembly                            D 52–28            2
# 30  House of Representatives                     D 45–24, 1 vac            2
# 31            State Assembly             D 103–42, 1 ind, 4 vac            2
# 32  House of Representatives                     R 64–55, 1 vac            2
# 33  House of Representatives                            R 79–15            4
# 34  House of Representatives                            R 61–38            2
# 35  House of Representatives                     R 77–23, 1 vac            2
# 36  House of Representatives                            D 38–22            2
# 37  House of Representatives                    R 109–93, 1 vac            2
# 38  House of Representatives                      D 66–8, 1 ind            2
# 39  House of Representatives                     R 78–45, 1 vac            2
# 40  House of Representatives                            R 59–11            2
# 41  House of Representatives                            R 73–26            2
# 42  House of Representatives                            R 83–67            2
# 43  House of Representatives                            R 59–16            2
# 44  House of Representatives                D 95–43, 7 P, 5 ind            2
# 45        House of Delegates                     D 55–44, 1 vac            2
# 46  House of Representatives                            D 57–41            2
# 47        House of Delegates                     R 58–41, 1 ind            2
# 48            State Assembly                     R 63–34, 2 vac            2
# 49  House of Representatives                      R 50–9, 1 Ind            2
#
#         up_house_name     up_party_strength up_term_yrs low_maj_party  \
# 0        State Senate                R 27–8           4             R
# 1              Senate                R 13–7           4
# 2              Senate               R 17–13           2             R
# 3              Senate                R 26–9           4             R
# 4        State Senate               D 29–11           4             D
# 5              Senate               D 19–16           4             D
# 6              Senate               D 22–14           2             D
# 7              Senate                D 12–9           4             D
# 8              Senate               R 23–17           4             R
# 9        State Senate               R 35–21           2             R
# 10             Senate                D 24–1           4             D
# 11             Senate                R 28–7           2             R
# 12             Senate               D 40–19      2 or 4             D
# 13             Senate               R 40–10           4             R
# 14             Senate               R 32–18           4             R
# 15             Senate               R 29–11           4             R
# 16             Senate               R 28–10           4             R
# 17       State Senate               R 27–12           4             R
# 18             Senate               D 21–14           2             D
# 19             Senate        D 32–14, 1 vac           4             D
# 20             Senate                D 36–4           2             D
# 21             Senate               R 22–16           4             R
# 22             Senate               R 35–32     2, 4, 4             D
# 23       State Senate        R 34-16, 2 vac           4             R
# 24             Senate         R 23–8, 3 vac           4             R
# 25             Senate               R 30–20           4             R
# 26  Legislature[nb 3]  R 30–18, 1 ind[nb 4]           4
# 27             Senate                D 13–8           4             D
# 28             Senate               D 14–10           2             D
# 29             Senate               D 25–15     2, 4, 4             D
# 30             Senate               D 26–16           4             D
# 31       State Senate        D 40–20, 3 vac           2             D
# 32             Senate        R 28–21, 1 vac           2             R
# 33             Senate               R 37–10           4             R
# 34             Senate                R 24–9           4             R
# 35             Senate         R 38–9, 1 vac           4             R
# 36       State Senate               D 18–12           4             D
# 37       State Senate        R 28–21, 1 ind           4             R
# 38             Senate                D 33–5           2             D
# 39             Senate               R 27–19           4             R
# 40             Senate                R 30–5           2             R
# 41             Senate                R 28–5           4             R
# 42             Senate               R 19–12           4             R
# 43             Senate                R 23–6           4             R
# 44             Senate           D 22–6, 2 P           2             D
# 45             Senate               D 21–19           4             D
# 46       State Senate               D 29–20           4             D
# 47             Senate               R 20–14           4             R
# 48       State Senate        R 18–13, 2 vac           4             R
# 49             Senate                R 27–3           4             R
#
#    low_maj_party_num low_min_party low_min_party_num up_maj_party  \
# 0                 75             D                28            R
# 1                                                               R
# 2                 31             D                29            R
# 3                 76             D                25            R
# 4                 61             R                17            D
# 5                 41             R                24            D
# 6                 91             R                60            D
# 7                 26             R                15            D
# 8                 72             D                46            R
# 9                105             D                75            R
# 10                46             R                 5            D
# 11                56             D                14            R
# 12                73             R                44            D
# 13                66             D                33            R
# 14                53             D                47            R
# 15                84             D                41            R
# 16                62             D                38            R
# 17                68             D                35            R
# 18                87             R                56            D
# 19                99             R                42            D
# 20               127             R                31            D
# 21                58             D                51            R
# 22                75             R                55            R
# 23                73             D                45            R
# 24               113             D                48            R
# 25                58             D                42            R
# 26                                                              R
# 27                29             R                13            D
# 28               231             R               158            D
# 29                52             R                28            D
# 30                45             R                24            D
# 31               103             R                42            D
# 32                64             D                55            R
# 33                79             D                15            R
# 34                61             D                38            R
# 35                77             D                23            R
# 36                38             R                22            D
# 37               109             D                93            R
# 38                66             R                 8            D
# 39                78             D                45            R
# 40                59             D                11            R
# 41                73             D                26            R
# 42                83             D                67            R
# 43                59             D                16            R
# 44                95             R                43            D
# 45                55             R                44            D
# 46                57             R                41            D
# 47                58             D                41            R
# 48                63             D                34            R
# 49                50             D                 9            R
#
#    up_maj_party_num up_min_party up_min_party_num low_vacancies up_vacancies
# 0                27            D                8             1          NaN
# 1                13            D                7           NaN          NaN
# 2                17            D               13           NaN          NaN
# 3                26            D                9             2          NaN
# 4                29            R               11             1          NaN
# 5                19            R               16           NaN          NaN
# 6                22            R               14           NaN          NaN
# 7                12            R                9           NaN          NaN
# 8                23            D               17             2          NaN
# 9                35            D               21           NaN          NaN
# 10               24            R                1           NaN          NaN
# 11               28            D                7           NaN          NaN
# 12               40            R               19             1          NaN
# 13               40            D               10             1          NaN
# 14               32            D               18           NaN          NaN
# 15               29            D               11           NaN          NaN
# 16               28            D               10           NaN          NaN
# 17               27            D               12           NaN          NaN
# 18               21            R               14             2          NaN
# 19               32            R               14           NaN            1
# 20               36            R                4             1          NaN
# 21               22            D               16             1          NaN
# 22               35            D               32           NaN          NaN
# 23               34            D               16             3            2
# 24               23            D                8             2            3
# 25               30            D               20           NaN          NaN
# 26               30            D               18           NaN          NaN
# 27               13            R                8           NaN          NaN
# 28               14            R               10            10          NaN
# 29               25            R               15           NaN          NaN
# 30               26            R               16             1          NaN
# 31               40            R               20             4            3
# 32               28            D               21             1            1
# 33               37            D               10           NaN          NaN
# 34               24            D                9           NaN          NaN
# 35               38            D                9             1            1
# 36               18            R               12           NaN          NaN
# 37               28            D               21             1          NaN
# 38               33            R                5           NaN          NaN
# 39               27            D               19             1          NaN
# 40               30            D                5           NaN          NaN
# 41               28            D                5           NaN          NaN
# 42               19            D               12           NaN          NaN
# 43               23            D                6           NaN          NaN
# 44               22            R                6           NaN          NaN
# 45               21            R               19             1          NaN
# 46               29            R               20           NaN          NaN
# 47               20            D               14           NaN          NaN
# 48               18            D               13             2            2
# 49               27            D                3           NaN          NaN
